# %% [markdown]
# # MNIST - Categorical Classification
# > # Model Capacity

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  - 1개의 Hidden Layer & 256개의 Nodes
#  - Model Capacity 낮게 조정

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

mnist = models.Sequential()
mnist.add(layers.Dense(256, activation = 'relu', input_shape=(28 * 28,)))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 2분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 4s 5ms/step - loss: 0.3258 - accuracy: 0.9088 - val_loss: 0.1785 - val_accuracy: 0.9493
# Epoch 2/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1465 - accuracy: 0.9583 - val_loss: 0.1269 - val_accuracy: 0.9643
# Epoch 3/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1001 - accuracy: 0.9703 - val_loss: 0.1139 - val_accuracy: 0.9668
# Epoch 4/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0748 - accuracy: 0.9784 - val_loss: 0.0960 - val_accuracy: 0.9728
# Epoch 5/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0593 - accuracy: 0.9830 - val_loss: 0.0884 - val_accuracy: 0.9750
# Epoch 6/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0467 - accuracy: 0.9861 - val_loss: 0.0874 - val_accuracy: 0.9752
# Epoch 7/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0377 - accuracy: 0.9892 - val_loss: 0.0858 - val_accuracy: 0.9758
# Epoch 8/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0306 - accuracy: 0.9912 - val_loss: 0.0874 - val_accuracy: 0.9768
# Epoch 9/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0249 - accuracy: 0.9931 - val_loss: 0.0855 - val_accuracy: 0.9778
# Epoch 10/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0198 - accuracy: 0.9945 - val_loss: 0.0884 - val_accuracy: 0.9771
# Epoch 11/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0158 - accuracy: 0.9961 - val_loss: 0.0889 - val_accuracy: 0.9781
# Epoch 12/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0128 - accuracy: 0.9967 - val_loss: 0.0926 - val_accuracy: 0.9769
# Epoch 13/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0105 - accuracy: 0.9974 - val_loss: 0.0871 - val_accuracy: 0.9792
# Epoch 14/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0081 - accuracy: 0.9978 - val_loss: 0.0928 - val_accuracy: 0.9778
# Epoch 15/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0066 - accuracy: 0.9985 - val_loss: 0.0946 - val_accuracy: 0.9783
# Epoch 16/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.0986 - val_accuracy: 0.9781
# Epoch 17/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 0.0997 - val_accuracy: 0.9800
# Epoch 18/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.1080 - val_accuracy: 0.9786
# Epoch 19/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.1123 - val_accuracy: 0.9786
# Epoch 20/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.1088 - val_accuracy: 0.9788
# Epoch 21/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1100 - val_accuracy: 0.9798
# Epoch 22/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.1109 - val_accuracy: 0.9796
# Epoch 23/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1130 - val_accuracy: 0.9797
# Epoch 24/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.7470e-04 - accuracy: 0.9999 - val_loss: 0.1203 - val_accuracy: 0.9792
# Epoch 25/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.0422e-04 - accuracy: 0.9998 - val_loss: 0.1206 - val_accuracy: 0.9799
# Epoch 26/100
# 375/375 [==============================] - 1s 4ms/step - loss: 5.1647e-04 - accuracy: 0.9999 - val_loss: 0.1273 - val_accuracy: 0.9793
# Epoch 27/100
# 375/375 [==============================] - 1s 4ms/step - loss: 5.4193e-04 - accuracy: 0.9998 - val_loss: 0.1252 - val_accuracy: 0.9804
# Epoch 28/100
# 375/375 [==============================] - 1s 4ms/step - loss: 3.7156e-04 - accuracy: 1.0000 - val_loss: 0.1338 - val_accuracy: 0.9802
# Epoch 29/100
# 375/375 [==============================] - 1s 4ms/step - loss: 3.4626e-04 - accuracy: 0.9999 - val_loss: 0.1329 - val_accuracy: 0.9793
# Epoch 30/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.6676e-04 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9797
# Epoch 31/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.8198e-04 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9800
# Epoch 32/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.5598e-04 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9795
# Epoch 33/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.6243e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9803
# Epoch 34/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.3461e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9808
# Epoch 35/100
# 375/375 [==============================] - 1s 4ms/step - loss: 7.1596e-05 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 0.9801
# Epoch 36/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.1491e-05 - accuracy: 1.0000 - val_loss: 0.1549 - val_accuracy: 0.9805
# Epoch 37/100
# 375/375 [==============================] - 1s 4ms/step - loss: 3.1168e-05 - accuracy: 1.0000 - val_loss: 0.1562 - val_accuracy: 0.9807
# Epoch 38/100
# 375/375 [==============================] - 1s 4ms/step - loss: 5.1555e-05 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.9812
# Epoch 39/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.7153e-05 - accuracy: 1.0000 - val_loss: 0.1671 - val_accuracy: 0.9808
# Epoch 40/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.2423e-05 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9810
# Epoch 41/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.2028e-05 - accuracy: 1.0000 - val_loss: 0.1727 - val_accuracy: 0.9810
# Epoch 42/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.3449e-05 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9819
# Epoch 43/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.8626e-05 - accuracy: 1.0000 - val_loss: 0.1755 - val_accuracy: 0.9808
# Epoch 44/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.5281e-06 - accuracy: 1.0000 - val_loss: 0.1802 - val_accuracy: 0.9808
# Epoch 45/100
# 375/375 [==============================] - 1s 4ms/step - loss: 4.9600e-06 - accuracy: 1.0000 - val_loss: 0.1779 - val_accuracy: 0.9802
# Epoch 46/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.7097e-05 - accuracy: 1.0000 - val_loss: 0.1797 - val_accuracy: 0.9805
# Epoch 47/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.6380e-06 - accuracy: 1.0000 - val_loss: 0.1842 - val_accuracy: 0.9798
# Epoch 48/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.6307e-06 - accuracy: 1.0000 - val_loss: 0.1876 - val_accuracy: 0.9804
# Epoch 49/100
# 375/375 [==============================] - 1s 4ms/step - loss: 6.3906e-07 - accuracy: 1.0000 - val_loss: 0.1882 - val_accuracy: 0.9811
# Epoch 50/100
# 375/375 [==============================] - 1s 4ms/step - loss: 4.6574e-07 - accuracy: 1.0000 - val_loss: 0.1911 - val_accuracy: 0.9807
# Epoch 51/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.4079e-07 - accuracy: 1.0000 - val_loss: 0.1880 - val_accuracy: 0.9813
# Epoch 52/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.5378e-07 - accuracy: 1.0000 - val_loss: 0.1900 - val_accuracy: 0.9813
# Epoch 53/100
# 375/375 [==============================] - 1s 4ms/step - loss: 6.5761e-08 - accuracy: 1.0000 - val_loss: 0.1917 - val_accuracy: 0.9809
# Epoch 54/100
# 375/375 [==============================] - 1s 4ms/step - loss: 5.1039e-08 - accuracy: 1.0000 - val_loss: 0.1929 - val_accuracy: 0.9814
# Epoch 55/100
# 375/375 [==============================] - 1s 4ms/step - loss: 4.1140e-08 - accuracy: 1.0000 - val_loss: 0.1948 - val_accuracy: 0.9812
# Epoch 56/100
# 375/375 [==============================] - 1s 4ms/step - loss: 3.8075e-08 - accuracy: 1.0000 - val_loss: 0.1946 - val_accuracy: 0.9818
# Epoch 57/100
# 375/375 [==============================] - 1s 4ms/step - loss: 3.2750e-08 - accuracy: 1.0000 - val_loss: 0.1953 - val_accuracy: 0.9815
# Epoch 58/100
# 375/375 [==============================] - 1s 4ms/step - loss: 3.0185e-08 - accuracy: 1.0000 - val_loss: 0.1961 - val_accuracy: 0.9813
# Epoch 59/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.8146e-08 - accuracy: 1.0000 - val_loss: 0.1966 - val_accuracy: 0.9813
# Epoch 60/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.6084e-08 - accuracy: 1.0000 - val_loss: 0.1967 - val_accuracy: 0.9812
# Epoch 61/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.4301e-08 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9813
# Epoch 62/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.2831e-08 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9814
# Epoch 63/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.1455e-08 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9816
# Epoch 64/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.0420e-08 - accuracy: 1.0000 - val_loss: 0.1996 - val_accuracy: 0.9813
# Epoch 65/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.9434e-08 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9815
# Epoch 66/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.8527e-08 - accuracy: 1.0000 - val_loss: 0.2002 - val_accuracy: 0.9813
# Epoch 67/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.7752e-08 - accuracy: 1.0000 - val_loss: 0.2005 - val_accuracy: 0.9816
# Epoch 68/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.6890e-08 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9812
# Epoch 69/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.6255e-08 - accuracy: 1.0000 - val_loss: 0.2017 - val_accuracy: 0.9817
# Epoch 70/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.5656e-08 - accuracy: 1.0000 - val_loss: 0.2016 - val_accuracy: 0.9812
# Epoch 71/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.5005e-08 - accuracy: 1.0000 - val_loss: 0.2022 - val_accuracy: 0.9812
# Epoch 72/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.4432e-08 - accuracy: 1.0000 - val_loss: 0.2019 - val_accuracy: 0.9814
# Epoch 73/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.4007e-08 - accuracy: 1.0000 - val_loss: 0.2025 - val_accuracy: 0.9815
# Epoch 74/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.3426e-08 - accuracy: 1.0000 - val_loss: 0.2026 - val_accuracy: 0.9814
# Epoch 75/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.3056e-08 - accuracy: 1.0000 - val_loss: 0.2032 - val_accuracy: 0.9817
# Epoch 76/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.2641e-08 - accuracy: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.9818
# Epoch 77/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.2288e-08 - accuracy: 1.0000 - val_loss: 0.2034 - val_accuracy: 0.9813
# Epoch 78/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.1983e-08 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9813
# Epoch 79/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.1538e-08 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9816
# Epoch 80/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.1382e-08 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.9812
# Epoch 81/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.0952e-08 - accuracy: 1.0000 - val_loss: 0.2054 - val_accuracy: 0.9813
# Epoch 82/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.0816e-08 - accuracy: 1.0000 - val_loss: 0.2052 - val_accuracy: 0.9812
# Epoch 83/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.0428e-08 - accuracy: 1.0000 - val_loss: 0.2057 - val_accuracy: 0.9815
# Epoch 84/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.0252e-08 - accuracy: 1.0000 - val_loss: 0.2062 - val_accuracy: 0.9812
# Epoch 85/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.9987e-09 - accuracy: 1.0000 - val_loss: 0.2060 - val_accuracy: 0.9813
# Epoch 86/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.8348e-09 - accuracy: 1.0000 - val_loss: 0.2063 - val_accuracy: 0.9814
# Epoch 87/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.6237e-09 - accuracy: 1.0000 - val_loss: 0.2066 - val_accuracy: 0.9812
# Epoch 88/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.3107e-09 - accuracy: 1.0000 - val_loss: 0.2066 - val_accuracy: 0.9812
# Epoch 89/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.2487e-09 - accuracy: 1.0000 - val_loss: 0.2069 - val_accuracy: 0.9812
# Epoch 90/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.9929e-09 - accuracy: 1.0000 - val_loss: 0.2072 - val_accuracy: 0.9810
# Epoch 91/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.8389e-09 - accuracy: 1.0000 - val_loss: 0.2072 - val_accuracy: 0.9812
# Epoch 92/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.6750e-09 - accuracy: 1.0000 - val_loss: 0.2078 - val_accuracy: 0.9813
# Epoch 93/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.5682e-09 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9812
# Epoch 94/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.4216e-09 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9809
# Epoch 95/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.2776e-09 - accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9811
# Epoch 96/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.1385e-09 - accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9812
# Epoch 97/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.0739e-09 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9811
# Epoch 98/100
# 375/375 [==============================] - 1s 4ms/step - loss: 7.8430e-09 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9812
# Epoch 99/100
# 375/375 [==============================] - 2s 4ms/step - loss: 7.7536e-09 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9812
# Epoch 100/100
# 375/375 [==============================] - 1s 4ms/step - loss: 7.6170e-09 - accuracy: 1.0000 - val_loss: 0.2094 - val_accuracy: 0.9811
# CPU times: user 2min 29s, sys: 24.8 s, total: 2min 54s
# Wall time: 2min 27s

# %% [markdown]
# > ## 4) 학습 결과 시각화 - Overfitting

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
plt.ylim(0, 0.25)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1822 - accuracy: 0.9806
# Loss = 0.18217
# Accuracy = 0.98060

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
