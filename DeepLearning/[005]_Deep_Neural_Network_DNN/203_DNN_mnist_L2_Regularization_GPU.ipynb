# %% [markdown]
# # MNIST - Categorical Classification
# > # L2 Regularization

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  - 2개의 Hidden Layers & 768개의 Nodes
#  - Model Capacity는 기존과 동일
#  - L2 Regularization 적용

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

mnist = models.Sequential()
mnist.add(layers.Dense(512, activation = 'relu',
                       kernel_regularizer = regularizers.l2(0.00001),
                       input_shape=(28 * 28,)))
mnist.add(layers.Dense(256, activation = 'relu',
                       kernel_regularizer = regularizers.l2(0.00001)))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 535,818
# Trainable params: 535,818
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 3분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 5s 4ms/step - loss: 0.2628 - accuracy: 0.9226 - val_loss: 0.1339 - val_accuracy: 0.9617
# Epoch 2/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1043 - accuracy: 0.9712 - val_loss: 0.1040 - val_accuracy: 0.9722
# Epoch 3/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0720 - accuracy: 0.9815 - val_loss: 0.0950 - val_accuracy: 0.9761
# Epoch 4/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0547 - accuracy: 0.9859 - val_loss: 0.1203 - val_accuracy: 0.9704
# Epoch 5/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0450 - accuracy: 0.9897 - val_loss: 0.0917 - val_accuracy: 0.9797
# Epoch 6/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0389 - accuracy: 0.9910 - val_loss: 0.1040 - val_accuracy: 0.9771
# Epoch 7/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0341 - accuracy: 0.9928 - val_loss: 0.0994 - val_accuracy: 0.9787
# Epoch 8/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0305 - accuracy: 0.9936 - val_loss: 0.0973 - val_accuracy: 0.9801
# Epoch 9/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0278 - accuracy: 0.9945 - val_loss: 0.1058 - val_accuracy: 0.9773
# Epoch 10/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0261 - accuracy: 0.9951 - val_loss: 0.1026 - val_accuracy: 0.9806
# Epoch 11/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0242 - accuracy: 0.9958 - val_loss: 0.1170 - val_accuracy: 0.9771
# Epoch 12/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0238 - accuracy: 0.9957 - val_loss: 0.1405 - val_accuracy: 0.9743
# Epoch 13/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0240 - accuracy: 0.9954 - val_loss: 0.1304 - val_accuracy: 0.9755
# Epoch 14/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0217 - accuracy: 0.9964 - val_loss: 0.1135 - val_accuracy: 0.9794
# Epoch 15/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0216 - accuracy: 0.9962 - val_loss: 0.1388 - val_accuracy: 0.9751
# Epoch 16/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0213 - accuracy: 0.9964 - val_loss: 0.1233 - val_accuracy: 0.9803
# Epoch 17/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0208 - accuracy: 0.9965 - val_loss: 0.1324 - val_accuracy: 0.9755
# Epoch 18/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0198 - accuracy: 0.9965 - val_loss: 0.1201 - val_accuracy: 0.9790
# Epoch 19/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0182 - accuracy: 0.9970 - val_loss: 0.1221 - val_accuracy: 0.9798
# Epoch 20/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0200 - accuracy: 0.9966 - val_loss: 0.1286 - val_accuracy: 0.9762
# Epoch 21/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0194 - accuracy: 0.9970 - val_loss: 0.1351 - val_accuracy: 0.9785
# Epoch 22/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0177 - accuracy: 0.9972 - val_loss: 0.1269 - val_accuracy: 0.9794
# Epoch 23/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0168 - accuracy: 0.9975 - val_loss: 0.1614 - val_accuracy: 0.9741
# Epoch 24/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0166 - accuracy: 0.9974 - val_loss: 0.1397 - val_accuracy: 0.9767
# Epoch 25/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0163 - accuracy: 0.9972 - val_loss: 0.1338 - val_accuracy: 0.9787
# Epoch 26/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0164 - accuracy: 0.9972 - val_loss: 0.1260 - val_accuracy: 0.9792
# Epoch 27/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0170 - accuracy: 0.9971 - val_loss: 0.1345 - val_accuracy: 0.9781
# Epoch 28/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0160 - accuracy: 0.9975 - val_loss: 0.1226 - val_accuracy: 0.9798
# Epoch 29/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0152 - accuracy: 0.9977 - val_loss: 0.1907 - val_accuracy: 0.9683
# Epoch 30/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0154 - accuracy: 0.9974 - val_loss: 0.1185 - val_accuracy: 0.9791
# Epoch 31/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0154 - accuracy: 0.9974 - val_loss: 0.1322 - val_accuracy: 0.9783
# Epoch 32/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0161 - accuracy: 0.9975 - val_loss: 0.1467 - val_accuracy: 0.9743
# Epoch 33/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0145 - accuracy: 0.9975 - val_loss: 0.1585 - val_accuracy: 0.9732
# Epoch 34/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0151 - accuracy: 0.9974 - val_loss: 0.1250 - val_accuracy: 0.9788
# Epoch 35/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0144 - accuracy: 0.9975 - val_loss: 0.1208 - val_accuracy: 0.9793
# Epoch 36/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0148 - accuracy: 0.9974 - val_loss: 0.1221 - val_accuracy: 0.9787
# Epoch 37/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0138 - accuracy: 0.9976 - val_loss: 0.1506 - val_accuracy: 0.9758
# Epoch 38/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0141 - accuracy: 0.9977 - val_loss: 0.1335 - val_accuracy: 0.9775
# Epoch 39/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0139 - accuracy: 0.9978 - val_loss: 0.1331 - val_accuracy: 0.9779
# Epoch 40/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0137 - accuracy: 0.9979 - val_loss: 0.1193 - val_accuracy: 0.9818
# Epoch 41/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0144 - accuracy: 0.9974 - val_loss: 0.1270 - val_accuracy: 0.9792
# Epoch 42/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0132 - accuracy: 0.9979 - val_loss: 0.1519 - val_accuracy: 0.9758
# Epoch 43/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0135 - accuracy: 0.9978 - val_loss: 0.1296 - val_accuracy: 0.9795
# Epoch 44/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0141 - accuracy: 0.9980 - val_loss: 0.1387 - val_accuracy: 0.9793
# Epoch 45/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0135 - accuracy: 0.9977 - val_loss: 0.1344 - val_accuracy: 0.9783
# Epoch 46/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0132 - accuracy: 0.9976 - val_loss: 0.1228 - val_accuracy: 0.9804
# Epoch 47/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0127 - accuracy: 0.9978 - val_loss: 0.1386 - val_accuracy: 0.9768
# Epoch 48/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0129 - accuracy: 0.9979 - val_loss: 0.1347 - val_accuracy: 0.9783
# Epoch 49/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0133 - accuracy: 0.9979 - val_loss: 0.1408 - val_accuracy: 0.9782
# Epoch 50/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0126 - accuracy: 0.9979 - val_loss: 0.1341 - val_accuracy: 0.9797
# Epoch 51/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0117 - accuracy: 0.9983 - val_loss: 0.1298 - val_accuracy: 0.9793
# Epoch 52/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0132 - accuracy: 0.9977 - val_loss: 0.1309 - val_accuracy: 0.9797
# Epoch 53/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0134 - accuracy: 0.9978 - val_loss: 0.1391 - val_accuracy: 0.9791
# Epoch 54/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0128 - accuracy: 0.9979 - val_loss: 0.1364 - val_accuracy: 0.9795
# Epoch 55/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0113 - accuracy: 0.9982 - val_loss: 0.1292 - val_accuracy: 0.9794
# Epoch 56/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0138 - accuracy: 0.9977 - val_loss: 0.1861 - val_accuracy: 0.9726
# Epoch 57/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0117 - accuracy: 0.9980 - val_loss: 0.1463 - val_accuracy: 0.9783
# Epoch 58/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0124 - accuracy: 0.9979 - val_loss: 0.1387 - val_accuracy: 0.9808
# Epoch 59/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0123 - accuracy: 0.9981 - val_loss: 0.1349 - val_accuracy: 0.9797
# Epoch 60/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0125 - accuracy: 0.9977 - val_loss: 0.1394 - val_accuracy: 0.9783
# Epoch 61/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0120 - accuracy: 0.9980 - val_loss: 0.1397 - val_accuracy: 0.9772
# Epoch 62/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0125 - accuracy: 0.9978 - val_loss: 0.1490 - val_accuracy: 0.9778
# Epoch 63/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.9980 - val_loss: 0.1481 - val_accuracy: 0.9772
# Epoch 64/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0124 - accuracy: 0.9978 - val_loss: 0.1366 - val_accuracy: 0.9778
# Epoch 65/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0109 - accuracy: 0.9983 - val_loss: 0.1573 - val_accuracy: 0.9770
# Epoch 66/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0107 - accuracy: 0.9982 - val_loss: 0.1613 - val_accuracy: 0.9756
# Epoch 67/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0103 - accuracy: 0.9984 - val_loss: 0.1495 - val_accuracy: 0.9781
# Epoch 68/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0118 - accuracy: 0.9981 - val_loss: 0.1591 - val_accuracy: 0.9761
# Epoch 69/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0111 - accuracy: 0.9981 - val_loss: 0.1423 - val_accuracy: 0.9793
# Epoch 70/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0112 - accuracy: 0.9982 - val_loss: 0.1283 - val_accuracy: 0.9805
# Epoch 71/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0104 - accuracy: 0.9983 - val_loss: 0.1362 - val_accuracy: 0.9784
# Epoch 72/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0115 - accuracy: 0.9980 - val_loss: 0.1529 - val_accuracy: 0.9755
# Epoch 73/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0118 - accuracy: 0.9981 - val_loss: 0.1506 - val_accuracy: 0.9783
# Epoch 74/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0114 - accuracy: 0.9979 - val_loss: 0.1476 - val_accuracy: 0.9787
# Epoch 75/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0099 - accuracy: 0.9986 - val_loss: 0.1285 - val_accuracy: 0.9813
# Epoch 76/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0112 - accuracy: 0.9983 - val_loss: 0.1258 - val_accuracy: 0.9801
# Epoch 77/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0107 - accuracy: 0.9985 - val_loss: 0.1366 - val_accuracy: 0.9792
# Epoch 78/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0106 - accuracy: 0.9984 - val_loss: 0.1468 - val_accuracy: 0.9777
# Epoch 79/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0117 - accuracy: 0.9981 - val_loss: 0.1335 - val_accuracy: 0.9792
# Epoch 80/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0111 - accuracy: 0.9981 - val_loss: 0.1559 - val_accuracy: 0.9777
# Epoch 81/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0110 - accuracy: 0.9981 - val_loss: 0.1631 - val_accuracy: 0.9759
# Epoch 82/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0113 - accuracy: 0.9980 - val_loss: 0.1302 - val_accuracy: 0.9793
# Epoch 83/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0106 - accuracy: 0.9979 - val_loss: 0.1424 - val_accuracy: 0.9776
# Epoch 84/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0107 - accuracy: 0.9983 - val_loss: 0.1607 - val_accuracy: 0.9768
# Epoch 85/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0111 - accuracy: 0.9982 - val_loss: 0.1588 - val_accuracy: 0.9787
# Epoch 86/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0107 - accuracy: 0.9981 - val_loss: 0.1765 - val_accuracy: 0.9758
# Epoch 87/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0105 - accuracy: 0.9981 - val_loss: 0.1793 - val_accuracy: 0.9758
# Epoch 88/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0107 - accuracy: 0.9983 - val_loss: 0.1454 - val_accuracy: 0.9781
# Epoch 89/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0100 - accuracy: 0.9983 - val_loss: 0.1569 - val_accuracy: 0.9754
# Epoch 90/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0092 - accuracy: 0.9985 - val_loss: 0.1658 - val_accuracy: 0.9755
# Epoch 91/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0106 - accuracy: 0.9982 - val_loss: 0.1500 - val_accuracy: 0.9808
# Epoch 92/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0104 - accuracy: 0.9984 - val_loss: 0.1332 - val_accuracy: 0.9802
# Epoch 93/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0103 - accuracy: 0.9982 - val_loss: 0.1355 - val_accuracy: 0.9799
# Epoch 94/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0108 - accuracy: 0.9981 - val_loss: 0.1542 - val_accuracy: 0.9783
# Epoch 95/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0093 - accuracy: 0.9984 - val_loss: 0.1764 - val_accuracy: 0.9735
# Epoch 96/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0108 - accuracy: 0.9981 - val_loss: 0.1582 - val_accuracy: 0.9772
# Epoch 97/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0108 - accuracy: 0.9981 - val_loss: 0.1529 - val_accuracy: 0.9776
# Epoch 98/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0092 - accuracy: 0.9985 - val_loss: 0.1450 - val_accuracy: 0.9797
# Epoch 99/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0105 - accuracy: 0.9982 - val_loss: 0.1544 - val_accuracy: 0.9781
# Epoch 100/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0095 - accuracy: 0.9985 - val_loss: 0.1682 - val_accuracy: 0.9783
# CPU times: user 2min 16s, sys: 17.7 s, total: 2min 34s
# Wall time: 2min 12s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
plt.ylim(0, 0.25)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1550 - accuracy: 0.9770
# Loss = 0.15500
# Accuracy = 0.97700

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
