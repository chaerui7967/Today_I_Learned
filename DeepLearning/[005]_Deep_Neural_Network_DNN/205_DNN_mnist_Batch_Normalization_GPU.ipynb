# %% [markdown]
# # MNIST - Categorical Classification
# > # Batch Normalization

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  * 활성화 함수의 입력값을 정규화 과정을 수행하여 전달
#  * Gradient Vanishing 문제 해결 및 더 큰 Learning Rate를 사용 가능

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

mnist = models.Sequential()
mnist.add(layers.Dense(512, input_shape=(28 * 28,)))
mnist.add(layers.BatchNormalization())
mnist.add(layers.Activation('relu'))
mnist.add(layers.Dense(256))
mnist.add(layers.BatchNormalization())
mnist.add(layers.Activation('relu'))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 538,890
# Trainable params: 537,354
# Non-trainable params: 1,536
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 3분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 6s 5ms/step - loss: 0.1808 - accuracy: 0.9459 - val_loss: 0.1118 - val_accuracy: 0.9652
# Epoch 2/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0726 - accuracy: 0.9776 - val_loss: 0.0845 - val_accuracy: 0.9743
# Epoch 3/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0468 - accuracy: 0.9855 - val_loss: 0.0839 - val_accuracy: 0.9748
# Epoch 4/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0333 - accuracy: 0.9898 - val_loss: 0.0945 - val_accuracy: 0.9745
# Epoch 5/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0251 - accuracy: 0.9918 - val_loss: 0.0920 - val_accuracy: 0.9763
# Epoch 6/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0174 - accuracy: 0.9941 - val_loss: 0.0833 - val_accuracy: 0.9802
# Epoch 7/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0148 - accuracy: 0.9952 - val_loss: 0.0846 - val_accuracy: 0.9797
# Epoch 8/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0116 - accuracy: 0.9961 - val_loss: 0.0998 - val_accuracy: 0.9745
# Epoch 9/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0101 - accuracy: 0.9966 - val_loss: 0.1144 - val_accuracy: 0.9762
# Epoch 10/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0091 - accuracy: 0.9972 - val_loss: 0.0895 - val_accuracy: 0.9815
# Epoch 11/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.1066 - val_accuracy: 0.9777
# Epoch 12/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0999 - val_accuracy: 0.9801
# Epoch 13/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.0975 - val_accuracy: 0.9803
# Epoch 14/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.1110 - val_accuracy: 0.9788
# Epoch 15/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.1167 - val_accuracy: 0.9805
# Epoch 16/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.1059 - val_accuracy: 0.9813
# Epoch 17/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.1133 - val_accuracy: 0.9795
# Epoch 18/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.1048 - val_accuracy: 0.9816
# Epoch 19/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0044 - accuracy: 0.9984 - val_loss: 0.1112 - val_accuracy: 0.9820
# Epoch 20/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 0.1069 - val_accuracy: 0.9819
# Epoch 21/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.1143 - val_accuracy: 0.9805
# Epoch 22/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.1353 - val_accuracy: 0.9793
# Epoch 23/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.1184 - val_accuracy: 0.9812
# Epoch 24/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.1191 - val_accuracy: 0.9814
# Epoch 25/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.1335 - val_accuracy: 0.9818
# Epoch 26/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.1216 - val_accuracy: 0.9827
# Epoch 27/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.1333 - val_accuracy: 0.9804
# Epoch 28/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.1149 - val_accuracy: 0.9812
# Epoch 29/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1290 - val_accuracy: 0.9806
# Epoch 30/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.1375 - val_accuracy: 0.9812
# Epoch 31/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1203 - val_accuracy: 0.9832
# Epoch 32/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.1350 - val_accuracy: 0.9812
# Epoch 33/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1339 - val_accuracy: 0.9804
# Epoch 34/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.1315 - val_accuracy: 0.9807
# Epoch 35/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.1321 - val_accuracy: 0.9820
# Epoch 36/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.1452 - val_accuracy: 0.9814
# Epoch 37/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.1387 - val_accuracy: 0.9824
# Epoch 38/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.1532 - val_accuracy: 0.9807
# Epoch 39/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.1679 - val_accuracy: 0.9796
# Epoch 40/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.1491 - val_accuracy: 0.9810
# Epoch 41/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.1423 - val_accuracy: 0.9825
# Epoch 42/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.1488 - val_accuracy: 0.9808
# Epoch 43/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.1493 - val_accuracy: 0.9815
# Epoch 44/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1411 - val_accuracy: 0.9825
# Epoch 45/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.1438 - val_accuracy: 0.9824
# Epoch 46/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.1580 - val_accuracy: 0.9816
# Epoch 47/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.1517 - val_accuracy: 0.9804
# Epoch 48/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.1621 - val_accuracy: 0.9815
# Epoch 49/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.8146e-04 - accuracy: 0.9997 - val_loss: 0.1588 - val_accuracy: 0.9829
# Epoch 50/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1494 - val_accuracy: 0.9827
# Epoch 51/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1554 - val_accuracy: 0.9817
# Epoch 52/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.1551 - val_accuracy: 0.9829
# Epoch 53/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.1618 - val_accuracy: 0.9809
# Epoch 54/100
# 375/375 [==============================] - 2s 5ms/step - loss: 8.9173e-04 - accuracy: 0.9996 - val_loss: 0.1573 - val_accuracy: 0.9832
# Epoch 55/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1738 - val_accuracy: 0.9819
# Epoch 56/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1522 - val_accuracy: 0.9826
# Epoch 57/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1649 - val_accuracy: 0.9836
# Epoch 58/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1802 - val_accuracy: 0.9813
# Epoch 59/100
# 375/375 [==============================] - 2s 5ms/step - loss: 8.8533e-04 - accuracy: 0.9997 - val_loss: 0.1727 - val_accuracy: 0.9820
# Epoch 60/100
# 375/375 [==============================] - 2s 5ms/step - loss: 8.3402e-04 - accuracy: 0.9997 - val_loss: 0.1562 - val_accuracy: 0.9833
# Epoch 61/100
# 375/375 [==============================] - 2s 4ms/step - loss: 5.4459e-04 - accuracy: 0.9998 - val_loss: 0.1755 - val_accuracy: 0.9810
# Epoch 62/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1738 - val_accuracy: 0.9812
# Epoch 63/100
# 375/375 [==============================] - 2s 5ms/step - loss: 9.0767e-04 - accuracy: 0.9998 - val_loss: 0.1781 - val_accuracy: 0.9797
# Epoch 64/100
# 375/375 [==============================] - 2s 5ms/step - loss: 8.6016e-04 - accuracy: 0.9998 - val_loss: 0.1607 - val_accuracy: 0.9817
# Epoch 65/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1708 - val_accuracy: 0.9810
# Epoch 66/100
# 375/375 [==============================] - 2s 5ms/step - loss: 8.0529e-04 - accuracy: 0.9998 - val_loss: 0.1587 - val_accuracy: 0.9818
# Epoch 67/100
# 375/375 [==============================] - 2s 5ms/step - loss: 5.6833e-04 - accuracy: 0.9998 - val_loss: 0.1518 - val_accuracy: 0.9822
# Epoch 68/100
# 375/375 [==============================] - 2s 4ms/step - loss: 7.1476e-04 - accuracy: 0.9998 - val_loss: 0.1678 - val_accuracy: 0.9824
# Epoch 69/100
# 375/375 [==============================] - 2s 5ms/step - loss: 8.3132e-04 - accuracy: 0.9997 - val_loss: 0.1619 - val_accuracy: 0.9822
# Epoch 70/100
# 375/375 [==============================] - 2s 5ms/step - loss: 8.1656e-04 - accuracy: 0.9997 - val_loss: 0.1540 - val_accuracy: 0.9826
# Epoch 71/100
# 375/375 [==============================] - 2s 5ms/step - loss: 5.7203e-04 - accuracy: 0.9998 - val_loss: 0.1571 - val_accuracy: 0.9838
# Epoch 72/100
# 375/375 [==============================] - 2s 5ms/step - loss: 5.4119e-04 - accuracy: 0.9998 - val_loss: 0.1680 - val_accuracy: 0.9830
# Epoch 73/100
# 375/375 [==============================] - 2s 5ms/step - loss: 7.7764e-04 - accuracy: 0.9998 - val_loss: 0.1723 - val_accuracy: 0.9812
# Epoch 74/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.3929e-04 - accuracy: 0.9998 - val_loss: 0.1734 - val_accuracy: 0.9829
# Epoch 75/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.9879e-04 - accuracy: 0.9998 - val_loss: 0.1729 - val_accuracy: 0.9826
# Epoch 76/100
# 375/375 [==============================] - 2s 5ms/step - loss: 6.6024e-04 - accuracy: 0.9998 - val_loss: 0.1801 - val_accuracy: 0.9825
# Epoch 77/100
# 375/375 [==============================] - 2s 5ms/step - loss: 4.5165e-04 - accuracy: 0.9998 - val_loss: 0.1818 - val_accuracy: 0.9817
# Epoch 78/100
# 375/375 [==============================] - 2s 5ms/step - loss: 7.3959e-04 - accuracy: 0.9997 - val_loss: 0.1665 - val_accuracy: 0.9832
# Epoch 79/100
# 375/375 [==============================] - 2s 5ms/step - loss: 4.5970e-04 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9826
# Epoch 80/100
# 375/375 [==============================] - 2s 5ms/step - loss: 7.9516e-04 - accuracy: 0.9996 - val_loss: 0.1885 - val_accuracy: 0.9813
# Epoch 81/100
# 375/375 [==============================] - 2s 5ms/step - loss: 5.1025e-04 - accuracy: 0.9998 - val_loss: 0.1844 - val_accuracy: 0.9823
# Epoch 82/100
# 375/375 [==============================] - 2s 5ms/step - loss: 6.1705e-04 - accuracy: 0.9998 - val_loss: 0.1755 - val_accuracy: 0.9830
# Epoch 83/100
# 375/375 [==============================] - 2s 5ms/step - loss: 2.7801e-04 - accuracy: 0.9999 - val_loss: 0.1831 - val_accuracy: 0.9827
# Epoch 84/100
# 375/375 [==============================] - 2s 5ms/step - loss: 4.3829e-04 - accuracy: 0.9999 - val_loss: 0.1802 - val_accuracy: 0.9826
# Epoch 85/100
# 375/375 [==============================] - 2s 5ms/step - loss: 5.5815e-04 - accuracy: 0.9998 - val_loss: 0.1821 - val_accuracy: 0.9819
# Epoch 86/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.1865 - val_accuracy: 0.9824
# Epoch 87/100
# 375/375 [==============================] - 2s 5ms/step - loss: 9.2126e-04 - accuracy: 0.9996 - val_loss: 0.2035 - val_accuracy: 0.9799
# Epoch 88/100
# 375/375 [==============================] - 2s 5ms/step - loss: 8.9607e-04 - accuracy: 0.9997 - val_loss: 0.1803 - val_accuracy: 0.9824
# Epoch 89/100
# 375/375 [==============================] - 2s 5ms/step - loss: 3.3322e-04 - accuracy: 0.9999 - val_loss: 0.1816 - val_accuracy: 0.9822
# Epoch 90/100
# 375/375 [==============================] - 2s 5ms/step - loss: 8.1369e-04 - accuracy: 0.9998 - val_loss: 0.1829 - val_accuracy: 0.9827
# Epoch 91/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1874 - val_accuracy: 0.9820
# Epoch 92/100
# 375/375 [==============================] - 2s 5ms/step - loss: 5.2667e-04 - accuracy: 0.9999 - val_loss: 0.1959 - val_accuracy: 0.9820
# Epoch 93/100
# 375/375 [==============================] - 2s 5ms/step - loss: 4.2760e-04 - accuracy: 0.9998 - val_loss: 0.2044 - val_accuracy: 0.9823
# Epoch 94/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.2034 - val_accuracy: 0.9822
# Epoch 95/100
# 375/375 [==============================] - 2s 5ms/step - loss: 3.8013e-04 - accuracy: 0.9998 - val_loss: 0.1999 - val_accuracy: 0.9830
# Epoch 96/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1912 - val_accuracy: 0.9830
# Epoch 97/100
# 375/375 [==============================] - 2s 5ms/step - loss: 4.8865e-04 - accuracy: 0.9998 - val_loss: 0.1850 - val_accuracy: 0.9822
# Epoch 98/100
# 375/375 [==============================] - 2s 5ms/step - loss: 7.5301e-04 - accuracy: 0.9998 - val_loss: 0.1951 - val_accuracy: 0.9833
# Epoch 99/100
# 375/375 [==============================] - 2s 5ms/step - loss: 6.3211e-04 - accuracy: 0.9999 - val_loss: 0.2218 - val_accuracy: 0.9806
# Epoch 100/100
# 375/375 [==============================] - 2s 5ms/step - loss: 2.8492e-04 - accuracy: 0.9999 - val_loss: 0.2268 - val_accuracy: 0.9803
# CPU times: user 3min 7s, sys: 20.5 s, total: 3min 28s
# Wall time: 3min 23s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
plt.ylim(0, 0.25)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1877 - accuracy: 0.9830
# Loss = 0.18770
# Accuracy = 0.98300

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
