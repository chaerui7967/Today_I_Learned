# %%
# !pip install pycaret

# %%
import pandas as pd

# %%
df = pd.read_csv('./Apart_Deal.csv')
df.columns = ['code', 'dong', 'date', 'apart_name','region_num', 'square', 'floor', 'blit_year', 'cost']

df.drop(['dong','apart_name','region_num'],axis=1, inplace=True)

space = df[df['floor']==' '].index
df.drop(space, inplace=True)

df['floor'] = df['floor'].astype('int')
# Out:
# /home/ubuntu/anaconda3/envs/multi/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4315702 entries, 0 to 4315702
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   code       int64
#  1   date       object
#  2   square     float64
#  3   floor      int64
#  4   blit_year  int64
#  5   cost       int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 230.5+ MB

# %%
from pycaret.regression import *
exp1 = setup(df, target = 'cost', ignore_features = ['date'])  # ,ignore_features=['Station code']
# Out:
# <style type="text/css">
# #T_22927_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_22927_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22927_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22927_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_22927_row0_col1" class="data row0 col1" >4118</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_22927_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_22927_row1_col1" class="data row1 col1" >cost</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_22927_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_22927_row2_col1" class="data row2 col1" >(4315702, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_22927_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_22927_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_22927_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_22927_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_22927_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_22927_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_22927_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_22927_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_22927_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_22927_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_22927_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_22927_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_22927_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_22927_row9_col1" class="data row9 col1" >(3020991, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_22927_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_22927_row10_col1" class="data row10 col1" >(1294711, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_22927_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_22927_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_22927_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_22927_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_22927_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_22927_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_22927_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_22927_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_22927_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_22927_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_22927_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_22927_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_22927_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_22927_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_22927_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_22927_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_22927_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_22927_row19_col1" class="data row19 col1" >bbda</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_22927_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_22927_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_22927_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_22927_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_22927_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_22927_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_22927_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_22927_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_22927_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_22927_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_22927_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_22927_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_22927_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_22927_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_22927_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_22927_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_22927_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_22927_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_22927_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_22927_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22927_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_22927_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_22927_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <t

# %%
compare_models()
# Out:
# IntProgress(value=0, description='Processing: ', max=89)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                 14:32:58
# Status     . . . . . . . . . . . . . . . . . .         Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Regressor
# <style type="text/css">
# #T_a4d0f_ th {
#   text-align: left;
# }
# #T_a4d0f_row0_col0, #T_a4d0f_row0_col1, #T_a4d0f_row0_col2, #T_a4d0f_row0_col3, #T_a4d0f_row0_col4, #T_a4d0f_row0_col5, #T_a4d0f_row0_col6, #T_a4d0f_row0_col7, #T_a4d0f_row1_col0, #T_a4d0f_row1_col1, #T_a4d0f_row1_col2, #T_a4d0f_row1_col3, #T_a4d0f_row1_col4, #T_a4d0f_row1_col5, #T_a4d0f_row1_col6, #T_a4d0f_row1_col7, #T_a4d0f_row2_col0, #T_a4d0f_row2_col1, #T_a4d0f_row2_col2, #T_a4d0f_row2_col3, #T_a4d0f_row2_col4, #T_a4d0f_row2_col5, #T_a4d0f_row2_col6, #T_a4d0f_row2_col7, #T_a4d0f_row3_col0, #T_a4d0f_row3_col1, #T_a4d0f_row3_col2, #T_a4d0f_row3_col3, #T_a4d0f_row3_col4, #T_a4d0f_row3_col5, #T_a4d0f_row3_col6, #T_a4d0f_row3_col7, #T_a4d0f_row4_col0, #T_a4d0f_row4_col1, #T_a4d0f_row4_col2, #T_a4d0f_row4_col3, #T_a4d0f_row4_col4, #T_a4d0f_row4_col5, #T_a4d0f_row4_col6, #T_a4d0f_row4_col7, #T_a4d0f_row5_col0, #T_a4d0f_row5_col1, #T_a4d0f_row5_col2, #T_a4d0f_row5_col3, #T_a4d0f_row5_col4, #T_a4d0f_row5_col5, #T_a4d0f_row5_col6, #T_a4d0f_row5_col7, #T_a4d0f_row6_col0, #T_a4d0f_row6_col1, #T_a4d0f_row6_col2, #T_a4d0f_row6_col3, #T_a4d0f_row6_col4, #T_a4d0f_row6_col5, #T_a4d0f_row6_col6, #T_a4d0f_row6_col7, #T_a4d0f_row7_col0, #T_a4d0f_row7_col1, #T_a4d0f_row7_col2, #T_a4d0f_row7_col3, #T_a4d0f_row7_col4, #T_a4d0f_row7_col5, #T_a4d0f_row7_col6, #T_a4d0f_row7_col7, #T_a4d0f_row8_col0, #T_a4d0f_row8_col1, #T_a4d0f_row8_col2, #T_a4d0f_row8_col3, #T_a4d0f_row8_col4, #T_a4d0f_row8_col5, #T_a4d0f_row8_col6, #T_a4d0f_row8_col7, #T_a4d0f_row9_col0, #T_a4d0f_row9_col1, #T_a4d0f_row9_col2, #T_a4d0f_row9_col3, #T_a4d0f_row9_col4, #T_a4d0f_row9_col5, #T_a4d0f_row9_col6, #T_a4d0f_row9_col7, #T_a4d0f_row10_col0, #T_a4d0f_row10_col1, #T_a4d0f_row10_col2, #T_a4d0f_row10_col3, #T_a4d0f_row10_col4, #T_a4d0f_row10_col5, #T_a4d0f_row10_col6, #T_a4d0f_row10_col7, #T_a4d0f_row11_col0, #T_a4d0f_row11_col1, #T_a4d0f_row11_col2, #T_a4d0f_row11_col3, #T_a4d0f_row11_col4, #T_a4d0f_row11_col5, #T_a4d0f_row11_col6, #T_a4d0f_row11_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_a4d0f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4d0f_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_a4d0f_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_a4d0f_row0_col1" class="data row0 col1" >4435.0520</td>
#       <td id="T_a4d0f_row0_col2" class="data row0 col2" >81108131.2000</td>
#       <td id="T_a4d0f_row0_col3" class="data row0 col3" >9005.8601</td>
#       <td id="T_a4d0f_row0_col4" class="data row0 col4" >0.8809</td>
#       <td id="T_a4d0f_row0_col5" class="data row0 col5" >0.1809</td>
#       <td id="T_a4d0f_row0_col6" class="data row0 col6" >0.1333</td>
#       <td id="T_a4d0f_row0_col7" class="data row0 col7" >26.2030</td>
#     </tr>
#     <tr>
#       <th id="T_a4d0f_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_a4d0f_row1_col0" class="data row1 col0" >Decision Tree Regressor</td>
#       <td id="T_a4d0f_row1_col1" class="data row1 col1" >4216.6954</td>
#       <td id="T_a4d0f_row1_col2" class="data row1 col2" >84980095.4240</td>
#       <td id="T_a4d0f_row1_col3" class="data row1 col3" >9218.3073</td>
#       <td id="T_a4d0f_row1_col4" class="data row1 col4" >0.8752</td>
#       <td id="T_a4d0f_row1_col5" class="data row1 col5" >0.1707</td>
#       <td id="T_a4d0f_row1_col6" class="data row1 col6" >0.1207</td>
#       <td id="T_a4d0f_row1_col7" class="data row1 col7" >5.3230</td>
#     </tr>
#     <tr>
#       <th id="T_a4d0f_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_a4d0f_row2_col0" class="data row2 col0" >Linear Regression</td>
#       <td id="T_a4d0f_row2_col1" class="data row2 col1" >11864.9535</td>
#       <td id="T_a4d0f_row2_col2" class="data row2 col2" >382299356.8000</td>
#       <td id="T_a4d0f_row2_col3" class="data row2 col3" >19552.1365</td>
#       <td id="T_a4d0f_row2_col4" class="data row2 col4" >0.4384</td>
#       <td id="T_a4d0f_row2_col5" class="data row2 col5" >0.6059</td>
#       <td id="T_a4d0f_row2_col6" class="data row2 col6" >0.4737</td>
#       <td id="T_a4d0f_row2_col7" class="data row2 col7" >0.4880</td>
#     </tr>
#     <tr>
#       <th id="T_a4d0f_level0_row3" class="row_heading level0 row3" >lasso</th>
#       <td id="T_a4d0f_row3_col0" class="data row3 col0" >Lasso Regression</td>
#       <td id="T_a4d0f_row3_col1" class="data row3 col1" >11864.9452</td>
#       <td id="T_a4d0f_row3_col2" class="data row3 col2" >382299350.4000</td>
#       <td id="T_a4d0f_row3_col3" class="data row3 col3" >19552.1365</td>
#       <td id="T_a4d0f_row3_col4" class="data row3 col4" >0.4384</td>
#       <td id="T_a4d0f_row3_col5" class="data row3 col5" >0.6059</td>
#       <td id="T_a4d0f_row3_col6" class="data row3 col6" >0.4737</td>
#       <td id="T_a4d0f_row3_col7" class="data row3 col7" >21.2330</td>
#     </tr>
#     <tr>
#       <th id="T_a4d0f_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_a4d0f_row4_col0" class="data row4 col0" >Ridge Regression</td>
#       <td id="T_a4d0f_row4_col1" class="data row4 col1" >11864.9524</td>
#       <td id="T_a4d0f_row4_col2" class="data row4 col2" >382299360.0000</td>
#       <td id="T_a4d0f_row4_col3" class="data row4 col3" >19552.1367</td>
#       <td id="T_a4d0f_row4_col4" class="data row4 col4" >0.4384</td>
#       <td id="T_a4d0f_row4_col5" class="data row4 col5" >0.6059</td>
#       <td id="T_a4d0f_row4_col6" class="data row4 col6" >0.4737</td>
#       <td id="T_a4d0f_row4_col7" class="data row4 col7" >0.1700</td>
#     </tr>
#     <tr>
#       <th id="T_a4d0f_level0_row5" class="row_heading level0 row5" >en</th>
#       <td id="T_a4d0f_row5_col0" class="data row5 col0" >Elastic Net</td>
#       <td id="T_a4d0f_row5_col1" class="data row5 col1" >11863.6688</td>
#       <td id="T_a4d0f_row5_col2" class="data row5 col2" >382300115.2000</td>
#       <td id="T_a4d0f_row5_col3" class="data row5 col3" >19552.1562</td>
#       <td id="T_a4d0f_row5_col4" class="data row5 col4" >0.4384</td>
#       <td id="T_a4d0f_row5_col5" class="data row5 col5" >0.6059</td>
#       <td id="T_a4d0f_row5_col6" class="data row5 col6" >0.4736</td>
#       <td id="T_a4d0f_row5_col7" class="data row5 col7" >21.1660</td>
#     </tr>
#     <tr>
#       <th id="T_a4d0f_level0_row6" class="row_heading level0 row6" >lar</th>
#       <td id="T_a4d0f_row6_col0" class="data row6 col0" >Least Angle Regression</td>
#       <td id="T_a4d0f_row6_col1" class="data row6 col1" >11864.9515</td>
#       <td id="T_a4d0f_row6_col2" class="data row6 col2" >382299347.0315</td>
#       <td id="T_a4d0f_row6_col3" class="data row6 col3" >19552.1364</td>
#       <td id="T_a4d0f_row6_col4" class="data row6 col4" >0.4384</td>
#       <td id="T_a4d0f_row6_col5" class="data row6 col5" >0.6059</td>
#       <td id="T_a4d0f_row6_col6" class="data row6 col6" >0.4737</td>
#       <td id="T_a4d0f_row6_col7" class="data row6 col7" >0.1870</td>
#     </tr>
#     <tr>
#       <th id="T_a4d0f_level0_row7" class="row_heading level0 row7" >br</th>
#       <td id="T_a4d0f_row7_col0" class="data row7 col0" >Bayesian Ridge</td>
#       <td id="T_a4d0f_row7_col1" class="data row7 col1" >11864.8978</td>
#       <td id="T_a4d0f_row7_col2" class="data row7 col2" >382299347.6471</td>
#       <td id="T_a4d0f_row7_col3" class="data row7 col3" >19552.1365</td>
#       <td id="T_a4d0f_row7_col4" class="data row7 col4" >0.4384</td>
#       <td id="T_a4d0f_row7_col5" class="data row7 col5" >0.6059</td>
#       <td id="T_a4d0f_row7_col6" class="data row7 col6" >0.4737</td>
#       <td id="T_a4d0f_row7_col7" class="data row7 col7" >0.4880</td>
#     </tr>
#     <tr>
#       <th id="T_a4d
